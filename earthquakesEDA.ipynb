# %% [markdown]
# ## earthquakes-EDA
#
# about the dataset
# - this dataset is downloaded from kaggle (link: https://www.kaggle.com/datasets/alessandrolobello/the-ultimate-earthquake-dataset-from-1990-2023 )
# - it is about earthquakes recorded from 1990-2023

# %%
data_filename = "/Users/koushikbabu/code/EDA/Eartquakes-1990-2023.csv"

# %% [markdown]
# ## Data Preparation

# %%
import pandas as pd
df = pd.read_csv(data_filename)

# %%
df
# Out:
#                   time                                     place     status  \
# 0         631153353990         12 km NNW of Meadow Lakes, Alaska   reviewed
# 1         631153491210                14 km S of Volcano, Hawaii   reviewed
# 2         631154083450                7 km W of Cobb, California   reviewed
# 3         631155512130      11 km E of Mammoth Lakes, California   reviewed
# 4         631155824490                    16km N of Fillmore, CA   reviewed
# ...                ...                                       ...        ...
# 3445746  1690626851941                5 km NW of Chikusei, Japan   reviewed
# 3445747  1690626975715              Kodiak Island region, Alaska  automatic
# 3445748  1690627215940  12 km W of Alberto Oviedo Mota, B.C., MX  automatic
# 3445749  1690628146040                        7 km W of Cobb, CA  automatic
# 3445750  1690628937884                 35 km W of Karluk, Alaska  automatic
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3445751 entries, 0 to 3445750
# Data columns (total 12 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   time          int64
#  1   place         object
#  2   status        object
#  3   tsunami       int64
#  4   significance  int64
#  5   data_type     object
#  6   magnitudo     float64
#  7   state         object
#  8   longitude     float64
#  9   latitude      float64
#  10  depth         float64
#  11  date          object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 315.5+ MB

# %%
missing_percentages = df.isna().sum()/len(df)
missing_percentages
# Out:
# time            0.0
# place           0.0
# status          0.0
# tsunami         0.0
# significance    0.0
# data_type       0.0
# magnitudo       0.0
# state           0.0
# longitude       0.0
# latitude        0.0
# depth           0.0
# date            0.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['time', 'place', 'status', 'tsunami', 'significance', 'data_type',
#        'magnitudo', 'state', 'longitude', 'latitude', 'depth', 'date'],
#       dtype='object')

# %% [markdown]
# ## columns we"ll analyze:
# - place
# - date
# - state
# - tsunami
# - status

# %% [markdown]
# ## state

# %%
df.state
# Out:
# 0               Alaska
# 1               Hawaii
# 2           California
# 3           California
# 4           California
#               ...
# 3445746          Japan
# 3445747         Alaska
# 3445748           B.C.
# 3445749     California
# 3445750         Alaska
# Name: state, Length: 3445751, dtype: object

# %%
state = df.state.unique()
len(state)
# Out:
# 858

# %%
states_by_earthquakes = df.state.value_counts()
states_by_earthquakes
# Out:
# state
#  California                     866675
#  Alaska                         777881
# California                      491689
#  Nevada                         174065
#  Hawaii                         125336
#                                  ...
#  CA Earthquake                       1
# south of the Chatham Islands         1
#  Eswatini                            1
#  Nigeria                             1
# North of the Virgin Islands          1
# Name: count, Length: 858, dtype: int64

# %%
states_by_earthquakes[:10]
# Out:
# state
#  California     866675
#  Alaska         777881
# California      491689
#  Nevada         174065
#  Hawaii         125336
#  Washington      80483
#  Utah            55471
#  Montana         53426
#  Indonesia       48502
#  Puerto Rico     46275
# Name: count, dtype: int64

# %%
type(states_by_earthquakes)
# Out:
# pandas.core.series.Series

# %%
states_by_earthquakes[:10].plot(kind="barh")
# Out:
# <Axes: ylabel='state'>

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
sns.distplot(states_by_earthquakes)
# Out:
# /var/folders/_p/bn3xfw2x40l2rlw2pgzs1gsm0000gn/T/ipykernel_3550/327349244.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(states_by_earthquakes)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
high_earthquake_states = states_by_earthquakes[states_by_earthquakes >= 1000]
low_earthquake_states = states_by_earthquakes[states_by_earthquakes < 1000]

# %%
len(high_earthquake_states)/ len(state)
# Out:
# 0.13986013986013987

# %%
sns.histplot(high_earthquake_states, log_scale=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='count', ylabel='Count'>

# %%
len(low_earthquake_states)
# Out:
# 738

# %% [markdown]
# ## date

# %%
df.date
# Out:
# 0          1990-01-01 00:22:33.990000+00:00
# 1          1990-01-01 00:24:51.210000+00:00
# 2          1990-01-01 00:34:43.450000+00:00
# 3          1990-01-01 00:58:32.130000+00:00
# 4          1990-01-01 01:03:44.490000+00:00
#                          ...
# 3445746    2023-07-29 10:34:11.941000+00:00
# 3445747    2023-07-29 10:36:15.715000+00:00
# 3445748    2023-07-29 10:40:15.940000+00:00
# 3445749    2023-07-29 10:55:46.040000+00:00
# 3445750    2023-07-29 11:08:57.884000+00:00
# Name: date, Length: 3445751, dtype: object

# %%
df.date = pd.to_datetime(df.date,format="mixed")

# %%
sns.histplot(df.date.dt.hour,bins=24)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='date', ylabel='Count'>

# %% [markdown]
# ## questions & answers
#
# 1. What is the distribution of earthquake statuses in the dataset?
# 2. How many earthquakes have been associated with tsunamis, and how many have not?
# 3. What is the significance level distribution of earthquakes?
# 4. What is the most common data type for earthquake records in the dataset?
# 5. What is the range of earthquake magnitudes in the dataset?
# 6. Which state or region has the highest frequency of earthquakes in the dataset?
# 7. What is the depth distribution of earthquakes in the dataset?
# 8. How has the frequency of earthquakes evolved over by year or month?
# 9. Are there any correlations between earthquake magnitude and depth?

# %% [markdown]
# ## place

# %%
place_counts = df['place'].value_counts()
print(place_counts)
# Out:
# place
# 6 km W of Cobb, California                  24202
# 7 km W of Cobb, California                  23821
# 8 km W of Cobb, California                  15288
# 37 km NNE of Amboy, Washington              14373
# 9 km W of Cobb, California                  11146
#                                             ...
# 1 km SE of Štore, Slovenia                      1
# 19 km ENE of Woodend, New Zealand               1
# 8 km SW of Bersezio, Italy                      1
# 1 km NW of Lédignan, France                     1
# 12 km W of Alberto Oviedo Mota, B.C., MX        1
# Name: count, Length: 531130, dtype: int64

# %% [markdown]
# ## status

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
df['status'].value_counts().plot(kind='bar')
plt.title('Distribution of Earthquake Status')
plt.xlabel('Status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ## tsunami

# %%
tsunami_counts = df['tsunami'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(tsunami_counts, labels=tsunami_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Tsunami Occurrence in Earthquakes')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='state', hue='status')
plt.title('Earthquake Status by State')
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Status')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %% [markdown]
# ## heatmap of 'status' vs. 'tsunami'

# %%
status_tsunami_crosstab = pd.crosstab(df['status'], df['tsunami'])
sns.heatmap(status_tsunami_crosstab, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Relationship between Status and Tsunami')
plt.xlabel('Tsunami')
plt.ylabel('Status')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['depth'], bins=20, edgecolor='k')
plt.title('Depth Distribution of Earthquakes')
plt.xlabel('Depth (km)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df['time'] = pd.to_datetime(df['time'])
df['year'] = df['time'].dt.year
earthquakes_by_year = df.groupby('year').size()
plt.figure(figsize=(12, 6))
earthquakes_by_year.plot(kind='line', marker='o')
plt.title('Earthquakes Over Time (by Year)')
plt.xlabel('Year')
plt.ylabel('Number of Earthquakes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='magnitudo', y='depth', alpha=0.5)
plt.title('Scatter Plot of Magnitude vs. Depth')
plt.xlabel('Magnitude')
plt.ylabel('Depth (km)')
plt.grid(True)
correlation = df['magnitudo'].corr(df['depth'])
print(f'Correlation coefficient between Magnitude and Depth: {correlation:.2f}')

plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Correlation coefficient between Magnitude and Depth: 0.36

# %% [markdown]
# ## geospecific analysis

# %%
import pandas as pd
import folium
map_center = [df['latitude'].mean(), df['longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=4)
for index, row in df.iterrows():
    folium.Marker([row['latitude'], row['longitude']], tooltip=row['place']).add_to(mymap)
mymap.save('earthquake_map.html')

# %% [markdown]
# ## correlation analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('Eartquakes-1990-2023.csv')
correlation_matrix = df[['magnitudo', 'depth']].corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
